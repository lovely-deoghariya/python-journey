# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely17_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Lovely"
print (len(name))
# Out:
# 6

# %%
name = input("enter your name")
print (len(name))
# Out:
# enter your nameLovely
# 6

# %%
print (len("python"))
# Out:
# 6

# %%
city = "gumla"
print (len(city))
# Out:
# 5

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruit = "mango"
print (fruit)
# Out:
# mango

# %%
print (len("Hi"))
# Out:
# 2

# %%
print ("Great job!")
# Out:
# Great job!

# %%
prin
