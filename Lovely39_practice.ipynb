# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely39_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a,b = 5,10
a,b = 5,10
print(a,b)
# Out:
# 5 10

# %%
#swap using a,b = b,a
a,b = 5,10
a,b = b,a
print(a,b)
# Out:
# 10 5

# %%
#print both value
a,b = 5,10
a,b = b,a
print(a,b)
# Out:
# 10 5

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#fruit variable
fruit = "Apple"
print(fruit)
# Out:
# Apple

# %%
#favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Red
# Red

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: count()
text = "banana"
print(text.count("a"))
# Out:
# 3

# %%
#Revision: find()
text = "Apple"
print(text.find("e"))
# Out:
# 4

# %%
#print "day 39 complete!"
print("Day 39 complete!")
# Out:
# Day 39 complete!
