# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely66_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: list count()

# %%
#create fruits = ["Apple","Mango","Apple"]
fruits = ['Apple', 'Mango', 'Apple']
print(fruits)
# Out:
# ['Apple', 'Mango', 'Apple']

# %%
#count "Apple"
fruits = ['Apple', 'Mango', 'Apple']
print(fruits.count('Apple'))
# Out:
# 2

# %%
#count "Banana"
fruits = ['Apple', 'Mango', 'Apple']
print(fruits.count('Banana'))
# Out:
# 0

# %%
#print list
fruits = ['Apple', 'Mango', 'Apple']
print(fruits)
# Out:
# ['Apple', 'Mango', 'Apple']

# %%
#print first item
fruits = ['Apple', 'Mango', 'Apple']
print(fruits[0])
# Out:
# Apple

# %%
#print last item
fruits = ['Apple', 'Mango', 'Apple']
print(fruits[-1])
# Out:
# Apple

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: append()
fruits = ['Apple', 'Mango']
fruits.append('Banana')
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#Revision: sort()
fruits = ['Mango', 'Apple', 'Banana']
fruits.sort()
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
#print "Day 66 complete!"
print("Day 66 complete!")
# Out:
# Day 66 complete!
