# %%
number1 = int(input("enter your first number:"))
number2 = int(input("enter your second number:"))
# Out:
# enter your first number:10
# enter your second number:20

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print (number1)
print (number2)
# Out:
# enter your first number15
# enter your second number25
# 15
# 25

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number "))
print ("addition", number1 +number2)
# Out:
# enter your first number15
# enter your second number 25
# addition 40

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("subtraction",number1-number2)
# Out:
# enter your first number40
# enter your second number20
# subtraction 20

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("multiplication",number1*number2)
# Out:
# enter your first number3
# enter your second number4
# multiplication 12

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("division",number1/number2)
# Out:
# enter your first number10
# enter your second number2
# division 5.0

# %%
print ("Great job !")
print ("You build your first calculator!")
# Out:
# Great job !
# You build your first calculator!

# %%
print ("made with ❤️ by lovely")
# Out:
# made with ❤️ by lovely
