# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely69_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: join list into a string

# %%
#create fruit list
fruits = ["Apple", "Mango", "Banana"]

# %%
#use "," .join (fruits)
fruits = ["Apple", "Mango", "Banana"]
result = ", ".join(fruits)
print(result)
# Out:
# Apple, Mango, Banana

# %%
#print result
fruits = ["Apple", "Mango", "Banana"]
result = ", ".join(fruits)
print(result)
# Out:
# Apple, Mango, Banana

# %%
#create colour list and join
colors = ["Red", "Blue", "Green"]
result = ", ".join(colors)
print(result)
# Out:
# Red, Blue, Green

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: copy()
fruits = ["Apple", "Mango"]
new_list = fruits.copy()
print(new_list)
# Out:
# ['Apple', 'Mango']

# %%
#Revision: in operator
fruits = ["Apple", "Mango", "Banana"]
print("Apple" in fruits)
# Out:
# True

# %%
#Revision: indexing
fruits = ["Apple", "Mango", "Banana"]
print(fruits[0])
# Out:
# Apple

# %%
#print "Day 69 complete!"
print("Day 69 complete!")
# Out:
# Day 69 complete!
