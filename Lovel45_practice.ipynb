# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovel45_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask user for name
name = input("Enter your name:")
print(name)
# Out:
# Enter your name:Lovely
# Lovely

# %%
#use strip()strip()
text = input("Enter text:")
print(text.strip())
# Out:
# Enter text:Python
# Python

# %%
#use title()
text = input("Enter text:")
print(text.title())
# Out:
# Enter text:good morning
# Good Morning

# %%
#print len(name)
name = "lovely"
print(len(name))
# Out:
# 6

# %%
#check isalpha()
text = input("Enter text:")
print(text.isalpha())
# Out:
# Enter text:Lovely
# True

# %%
#print first letter
word = "python"
print(word[0])
# Out:
# p

# %%
#print last letter
word = "python"
print(word[-1])
# Out:
# n

# %%
#Revision: count("a")
text = "banana"
print(text.count("a"))
# Out:
# 3

# %%
#Revision: upper()
name = input("enter your name:")
print(name.upper())
# Out:
# enter your name:Lovely
# LOVELY

# %%
#print "Day 45 complete!"
print("Day 45 complete!")
# Out:
# Day 45 complete!
