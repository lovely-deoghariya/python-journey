# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely63_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: list sort()

# %%
#create numbers = [5,2,9,1]
numbers = [5, 2, 9, 1]

# %%
#sort the list
numbers.sort()

# %%
#print sorted list
numbers = [5, 2, 9, 1]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 5, 9]

# %%
#create fruits list and sort it
fruits = ["mango", "apple", "banana", "orange"]
fruits.sort()
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit")
print(fruit)
# Out:
# Enter your favorite fruitMango
# Mango

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: len(list)
fruits = ["apple", "banana", "mango"]
print(len(fruits))
# Out:
# 3

# %%
#Revision: indexing
fruits = ["apple", "banana", "mango"]
print(fruits[0])   # First item
print(fruits[1])   # Second item
print(fruits[-1])  # Last item
# Out:
# apple
# banana
# mango

# %%
#print "Day 62 complete!"
print ("Day 62 complete!")
# Out:
# Day 62 complete!
