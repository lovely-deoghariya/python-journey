# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely46_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Print "Python" .swapcase ()
print("Python".swapcase())
# Out:
# pYTHON

# %%
#Print "GOOD morning" .swapcase()
print("GOOD morning".swapcase())
# Out:
# good MORNING

# %%
#Ask user for text and print .swapcase ()
text = input("enter text:")
print(text.swapcase())
# Out:
# enter text:Lovely Deoghariya
# lOVELY dEOGHARIYA

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "watermelon"
print(fruit)
# Out:
# watermelon

# %%
#Ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:White
# White

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: title()
name = "lovely"
print(name.title())
# Out:
# Lovely

# %%
#Revision: capitalize()
name = "lovely"
print(name.capitalize())
# Out:
# Lovely

# %%
#print "Day 46 complete!"
print("Day 46 complete!")
# Out:
# Day 46 complete!
