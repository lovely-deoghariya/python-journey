# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely31_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "banana" .count("a")
print("banana".count("a"))
# Out:
# 3

# %%
#count "l" in "lovely"
print("lovely".count("l"))
# Out:
# 2

# %%
#ask user for a word and count "a"
word = input("enter a word:")
print(word.count("a")

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "Apple"
print(fruit)
# Out:
# Apple

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Pink
# Pink

# %%
#print "keep learning"
print("keep learning")
# Out:
# keep learning

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 31 complete!"
print("Day 31 complete!")
# Out:
# Day 31 complete!
