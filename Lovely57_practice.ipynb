# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely57_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: Remove items from the list

# %%
#Create fruits = ["Apple","Mango","Banana"]
fruits = ["Apple", "Mango", "Banana"]

# %%
#Remove "mango"
fruits = ["Apple", "Mango", "Banana"]
fruits.remove("Mango")

# %%
#print the updated list
fruits = ["Apple", "Mango", "Banana"]
fruits.remove("Mango")
print(fruits)
# Out:
# ['Apple', 'Banana']

# %%
#print the last item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[-1])
# Out:
# Banana

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Banana
# Banana

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: append()
fruits = ["Apple", "Mango"]
fruits.append("Banana")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#Revision: indexing
fruits = ["Apple", "Mango", "Banana"]
print(fruits[1])
# Out:
# Mango

# %%
#print "Day 57 complete!"
print("Day 57 complete!")
# Out:
# Day 57 complete!
