# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely51_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print a message using triple quotes
print("""Hello Lovely!
Welcome to Python.
Keep Learning!""")
# Out:
# Hello Lovely!
# Welcome to Python.
# Keep Learning!

# %%
#print a 3 line poem
print("""Roses are red,
Sky is blue,
Python is fun!""")
# Out:
# Roses are red,
# Sky is blue,
# Python is fun!

# %%
#Store a multi line string in a variable
text = """This is line 1.
This is line 2.
This is line 3."""
print(text)
# Out:
# This is line 1.
# This is line 2.
# This is line 3.

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Create a fruit variable
fruit = "mango"
print(fruit)
# Out:
# mango

# %%
#Ask favourite colour
color = input("Enter your favorite color: ")
print(color)
# Out:
# Enter your favorite color: Black
# Black

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: f-string
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Enter your name: Lovely
# Hello, Lovely !

# %%
#Revision: len()
name = "lovely"
print(len(name))
# Out:
# 6

# %%
#print "Day 51 complete!"
print("Day 51 complete!")
# Out:
# Day 51 complete!
