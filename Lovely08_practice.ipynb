# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely08_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Lovely")
colour = input("Your favourite colour")
# Out:
# Lovely
# Your favourite colourBlack

# %%
book = "maths"
pages = "546"
city = "gumla"
print (book)
print (pages)
print (city)
# Out:
# maths
# 546
# gumla

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("sum",number1+number2)
# Out:
# enter your first number2
# enter your second number3
# sum 5

# %%
print (5==5)
# Out:
# True

# %%
print (7==3)
# Out:
# False

# %%
#create marks = 50 use if else to print pass if marks ==50 otherwise try again
marks = 50
if marks ==50:
    print ("pass")
else:
    print ("try again")
# Out:
# pass

# %%
#create lucky = 8 print yes if lucky == 8 otherwise no
lucky = 8
if lucky ==8:
    print ("yes")
else:
    print("no")
# Out:
# yes

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (3):
    print ("I can do it!")
# Out:
# I can do it!
# I can do it!
# I can do it!

# %%
print ("see you tomorrow for day 9!❤️")
# Out:
# see you tomorrow for day 9!❤️
