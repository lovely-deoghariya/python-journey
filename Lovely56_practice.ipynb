# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely56_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: Add items to a list (. append())

# %%
#create fruits = ["Apple","Mango"]
fruits = ["Apple", "Mango"]

# %%
#Add "Banana" using append()
fruits = ["Apple", "Mango"]
fruits.append("Banana")

# %%
#print the update list
fruits = ["Apple", "Mango"]
fruits.append("Banana")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#print the first them
fruits = ["Apple", "Mango"]
print(fruits[0])
# Out:
# Apple

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Mango
# Mango

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: list length
fruits = ["Apple", "Mango", "Banana"]
print(len(fruits))
# Out:
# 3

# %%
#Revision: f-string greeting
name = input("Enter your name: ")
print(f"Hello {name}")
# Out:
# Enter your name: Vishal
# Hello Vishal

# %%
#print "Day 56 complete!"
print("Day 56 complete!")
# Out:
# Day 56 complete!
