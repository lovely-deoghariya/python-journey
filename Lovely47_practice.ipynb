# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely47_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "Hi" .center()
print("Hi".center(10))
# Out:
#     Hi

# %%
#center "Lovely" in 15 spaces
print("Lovely".center(15))
# Out:
#      Lovely

# %%
#Ask user for a word and center it
word = input("enter a word:")
print(word.center(15))
# Out:
# enter a word:Vishal
#      Vishal

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "mango"
print(fruit)
# Out:
# mango

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Pink
# Pink

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: upper()
name = "lovely"
print(name.upper())
# Out:
# LOVELY

# %%
#Revision: lower()
name = "LOVELY"
print(name.lower())
# Out:
# lovely

# %%
#print " Day 47 complete!"
print("Day 47 complete!")
# Out:
# Day 47 complete!
