# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely26_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#word = "python"; print(word[-1])
word = "python"
print(word[-1])
# Out:
# n

# %%
#print second last letter
word = "python"
print(word[-2])
# Out:
# o

# %%
#print first and last letter
word = "python"
print(word[0],word[-1])
# Out:
# p n

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "banana"
print(fruit)
# Out:
# banana

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Red
# Red

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 26 complete!"
print("Day 26 complete!")
# Out:
# Day 26 complete!
