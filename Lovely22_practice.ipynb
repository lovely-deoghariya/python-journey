# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely22_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create test = "I like tea" and replace tea with coffee
test = "I like tea"
print(test.replace("tea","coffee"))
# Out:
# I like coffee

# %%
#print "banana" replace ('a','*')
print("banana".replace("a","*"))
# Out:
# b*n*n*

# %%
#ask user for a word and replace first letter with "*"
word = input("enter a word:")
print(word.replace(word[0],"*",1))

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "lichi"
print(fruit)
# Out:
# lichi

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Black
# Black

# %%
#print "keep learning!"
print("keep learning")
# Out:
# keep learning

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 22 complete!"
print("Day 22 complete!")
# Out:
# Day 22 complete!
