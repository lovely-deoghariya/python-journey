# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely36_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "abc123, . isalnum()
print("abc123".isalnum())
# Out:
# True

# %%
#print "abc!" .isalnum ()
print("abc!".isalnum())
# Out:
# False

# %%
#ask user for text and .isalnum()
text = input("enter text:")
print(text.isalnum())
# Out:
# enter text:Abc123
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#fruit variable
fruit = "Apple"
print(fruit)
# Out:
# Apple

# %%
#favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Black
# Black

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: isalpha()
print("lovely".isalpha())
# Out:
# True

# %%
#Revision: isdigit()
print("12345".isdigit())
# Out:
# True

# %%
#print (day 36 complete!"
print("Day 36 complete!")
# Out:
# Day 36 complete!
