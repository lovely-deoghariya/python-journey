# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely52__practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "Python" [::2]
print("Python"[::2])
# Out:
# Pto

# %%
#print every second letter of "lovely"
print("Lovely"[::2])
# Out:
# Lvl

# %%
#print reversed using [::-1]
print("python"[::-1])
# Out:
# nohtyp

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "lichi"
print(fruit)
# Out:
# lichi

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Purple 💜
# Purple 💜

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: first letter
name = "lovely"
print(name[0])
# Out:
# l

# %%
#Revision: last letter
name = "lovely"
print(name[-1])
# Out:
# y

# %%
#print "Day 52 complete!"
print("Day 52 complete!")
# Out:
# Day 52 complete!
