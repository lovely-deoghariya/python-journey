# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely25%20practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#word = "python";print (word[0:3])
word = "python"
print(word[0:3])
# Out:
# pyt

# %%
#print first 2 letters of "lovely"
name = "lovely"
print(name[0:2])
# Out:
# lo

# %%
#print last 3 letters using slicing
name = "lovely"
print(name[-3:])
# Out:
# ely

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "lichi"
print(fruit)
# Out:
# lichi

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Pink
# Pink

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 25 complete!"
print("Day 25 complete!")
# Out:
# Day 25 complete!
