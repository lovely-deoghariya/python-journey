# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely40_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask name
name = input("enter your name:")
print("your name is:", name)
# Out:
# enter your name:Lovely
# your name is: Lovely

# %%
#use strip()
name = input("Enter your name:")
name = name.strip()
print("Your name is:", name)
# Out:
# Enter your name:Lovely
# Your name is: Lovely

# %%
#use title()
name = input("enter your name:").strip().title()
print("your name is:", name)
# Out:
# enter your name:Lovely Deoghariya
# your name is: Lovely Deoghariya

# %%
#print len(name)
name = "lovely"
print(len(name))
# Out:
# 6

# %%
#check isalpha()
name = input("enter your name:")
print(name.isalpha())
# Out:
# enter your name:Lovely
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#favourite fruit
fruit = input("enter your favourite fruit:")
print(fruit)
# Out:
# enter your favourite fruit:Lichi
# Lichi

# %%
#Revision: startswith("a")
text = input("enter text:")
print(text.startswith("a"))
# Out:
# enter text:apple
# True

# %%
#Revision: endswith("a")
text = input("enter text:")
print(text.endswith("a"))
# Out:
# enter text:Banana
# True

# %%
#print "day 40 complete!"
print("Day 40 complete!")
# Out:
# Day 40 complete!
