# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely33_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "123" .isdigit()
print("123".isdigit())
# Out:
# True

# %%
#print "12a" .isdigit()
print("12a".isdigit())
# Out:
# False

# %%
#ask user for input and check .isdigit()
text = input("enter a value:")
print(text.isdigit())
# Out:
# enter a value:12345
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "lichi"
print(fruit)
# Out:
# lichi

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Yellow
# Yellow

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: upper()
text = input("enter your name:")
print(text.upper())
# Out:
# enter your name:Lovely
# LOVELY

# %%
#Revision: lower()
text = input("enter your name:")
print(text.lower())
# Out:
# enter your name:Lovely
# lovely

# %%
#print "day 33 complete!"
print("Day 33 complete!")
# Out:
# Day 33 complete!
