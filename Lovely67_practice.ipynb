# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely67_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: list index()

# %%
#create fruit list
fruits = ['Apple', 'Mango', 'Banana']
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#find index of "mango"
fruits = ['Apple', 'Mango', 'Banana']
print(fruits.index('Mango'))
# Out:
# 1

# %%
#find index of "Apple"
fruits = ['Apple', 'Mango', 'Banana']
print(fruits.index('Apple'))
# Out:
# 0

# %%
#print list
fruits = ['Apple', 'Mango', 'Banana']
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Apple
# Apple

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: count()
fruits = ['Apple', 'Mango', 'Apple']
print(fruits.count('Apple'))
# Out:
# 2

# %%
#Revision: reverse()
fruits = ['Apple', 'Mango', 'Banana']
fruits.reverse()
print(fruits)
# Out:
# ['Banana', 'Mango', 'Apple']

# %%
#print "Day 67 complete!"
print("Day 67 complete!")
# Out:
# Day 67 complete!
