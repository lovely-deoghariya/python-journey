# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely49_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#name = "lovely" ; print (f"Hi{name}")
name = "lovely"
print(f"Hi {name}")
# Out:
# Hi lovely

# %%
#Create age = 20 and print using f-string
age = 20
print(f"Age: {age}")
# Out:
# Age: 20

# %%
#Ask user for name and greet using f-string
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Enter your name: Lovely
# Hello, Lovely!

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "watermelon"
print(fruit)
# Out:
# watermelon

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Green
# Green

# %%
#Revision: title()
name = "lovely"
print(name.title())
# Out:
# Lovely

# %%
#Print "Day 49 complete!"
print("Day 49 complete!")
# Out:
# Day 49 complete!
