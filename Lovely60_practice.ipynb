# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely60_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: mini list project

# %%
#create a fruit list
fruits = ["Apple", "Mango", "Banana"]

# %%
#add one fruit
fruits = ["Apple", "Mango", "Banana"]
fruits.append("Orange")

# %%
#Remove one fruit
fruits = ["Apple", "Mango", "Banana"]
fruits.remove("Mango")

# %%
#print the list
fruits = ["Apple", "Mango", "Banana"]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#print the list length
fruits = ["Apple", "Mango", "Banana"]
print(len(fruits))
# Out:
# 3

# %%
#check if "apple" is in the list
fruits = ["Apple", "Mango", "Banana"]
print("Apple" in fruits)
# Out:
# True

# %%
#print the first item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[0])
# Out:
# Apple

# %%
#print the last item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[-1])
# Out:
# Banana

# %%
#print a message using a f-string
name = input("Enter your name: ")
print(f"Hello {name}, keep learning Python!")
# Out:
# Enter your name: Lovely
# Hello Lovely , keep learning Python!

# %%
#print "Day 60 complete!"
print("Day 60 Complete!")
# Out:
# Day 60 Complete!
