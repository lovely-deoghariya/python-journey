# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely55_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: mini list practice

# %%
#create a fruit list
fruits = ["Apple", "Mango", "Banana"]

# %%
#print all items
fruits = ["Apple", "Mango", "Banana"]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#print first items
fruits = ["Apple", "Mango", "Banana"]
print(fruits[0])
# Out:
# Apple

# %%
#print last items
fruits = ["Apple", "Mango", "Banana"]
print(fruits[-1])
# Out:
# Banana

# %%
#Ask user for favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Watermelon 🍉
# Watermelon 🍉

# %%
#print greeting with f-string
name = input("Enter your name: ")
print(f"Hello {name}")
# Out:
# Enter your name: Vishal
# Hello Vishal

# %%
#print list length
fruits = ["Apple", "Mango", "Banana"]
print(len(fruits))
# Out:
# 3

# %%
#Revision: string slicing
text = "Python"
print(text[0:3])
# Out:
# Pyt

# %%
#Revision: isalpha()
text = input("Enter text: ")
print(text.isalpha())
# Out:
# Enter text: Lovely
# True

# %%
#print "Day 55 complete!"
print("Day 55 complete!")
# Out:
# Day 55 complete!
