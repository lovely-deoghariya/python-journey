# %%
#print your name and your favourite food
print ("Lovely")
print ("Biryani")
# Out:
# Lovely
# Biryani

# %%
#creat variables
name = "lovely"
age = "21"
city = "gumla"
print (name)
print (age)
print (city)
# Out:
# lovely
# 21
# gumla

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("sum",number1+number2)
# Out:
# enter your first number10
# enter your second number20
# sum 30

# %%
#ask the user their favourite fruit
fruit = input("enter your favourite fruit:")
#print the massage
print ("I like", fruit,"too!")
# Out:
# enter your favourite fruit:Mango
# I like Mango  too!

# %%
#create marks variables
marks = 42
#check pass or fail
if marks >= 35:
    print ("pass")
else:
    print ("fail")
# Out:
# pass

# %%
#ask the user for their age
age = int(input("enter your age:"))
#check if the user is an adult or minor
if age >=18:
    print ("adult")
else:
    print ("minor")
# Out:
# enter your age:21
# adult

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (5):
    print ("❤️")
# Out:
# ❤️
# ❤️
# ❤️
# ❤️
# ❤️

# %%
print (20>15)
# Out:
# True

# %%
print (see you tomorrow for day 6!
