# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely64_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: loop through a list

# %%
#create fruit list
fruits = ["apple", "banana", "mango"]

# %%
#use for loop to print each fruit
fruits = ["apple", "banana", "mango"]

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# mango

# %%
#print number 1 to 3
for i in range(1, 4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
#create colour list
colors = ["red", "blue", "green"]

# %%
#print each colour
colors = ["red", "blue", "green"]

for color in colors:
    print(color)
# Out:
# red
# blue
# green

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: reverse()
numbers = [1, 2, 3]
numbers.reverse()
print(numbers)
# Out:
# [3, 2, 1]

# %%
#Revision: in operation
fruits = ["apple", "banana", "mango"]
print("apple" in fruits)
# Out:
# True

# %%
#Revision: len(list)
colors = ["red", "blue", "green"]
print(len(colors))
# Out:
# 3

# %%
#print "Day 64 complete!"
print("Day 64 complete!")
# Out:
# Day 64 complete!
