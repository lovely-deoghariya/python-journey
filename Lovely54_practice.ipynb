# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely54_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: Access list them

# %%
#Create a fruit list
fruits = ["Apple", "Mango", "Banana"]

# %%
#print first item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[0])
# Out:
# Apple

# %%
#print second item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[1])
# Out:
# Mango

# %%
#print last item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[1])
# Out:
# Mango

# %%
#print 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Mango
# Mango

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: len(list)
fruits = ["Apple", "Mango", "Banana"]
print(len(fruits))
# Out:
# 3

# %%
#Revision: title()
name = input("Enter your name: ")
print(name.title())
# Out:
# Enter your name: Vishal
# Vishal

# %%
#print "Day 54 complete!"
print("Day 54 complete!")
# Out:
# Day 54 complete!
