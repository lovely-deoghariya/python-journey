# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely13_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Print true and true using and
print (True and True)
# Out:
# True

# %%
print (5>2 and 8>2)
# Out:
# True

# %%
print (5>8 and 8>3)
# Out:
# False

# %%
age = 18
marks = 35
if age ==18 and marks >=35:
    print ("Eligible")
# Out:
# Eligible

# %%
#create two variables and print them
name = "lovely"
age = "21"
print (name)
print (age)
# Out:
# lovely
# 21

# %%
for i in range (1,5):
    print (i)
# Out:
# 1
# 2
# 3
# 4

# %%
#ask the user for their name
name = input("enter your name:")
print ("Hello",name)
# Out:
# enter your name:Lovely
# Hello Lovely

# %%
print (10>5 and 2>8)
# Out:
# False

# %%
print ("well done")
# Out:
# well done

# %%
print ("Day 13
