# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely01_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("i love you BBD")
# Out:
# i love you BBD

# %%
print ("lovely")
print ("vishal")
# Out:
# lovely
# vishal

# %%
print ("lovely vishal")
# Out:
# lovely vishal

# %%
a=2
b=2
print (a+b)
# Out:
# 4

# %%
current_age = 21
age_after_5_years = current_age+ 5
print (age_after_5_years)
# Out:
# 26

# %%
for i in range (5):
    print ("❤️")
# Out:
# ❤️
# ❤️
# ❤️
# ❤️
# ❤️

# %%
for i in range (5):
    print ("Good morning betuuu ❤️")
# Out:
# Good morning betuuu ❤️
# Good morning betuuu ❤️
# Good morning betuuu ❤️
# Good morning betuuu ❤️
# Good morning betuuu ❤️

# %%
name = input ("enter your name:")
print ("Hi,", name , "!")
# Out:
# enter your name:vishal
# Hi, vishal  !

# %%
Chocolate = input ("enter your favourite chocolate:")
print ("great choice")
# Out:
# enter your favourite chocolate:Kitkat
# great choice

# %%
Colour = input ("enter your favourite colour:")
print (colour)
# Out:
# enter your favourite colour:Black
# Black

# %%
print (10>5)
# Out:
# True
