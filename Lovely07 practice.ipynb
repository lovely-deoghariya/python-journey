# %%
print ("Name = Lovely")
print ("Your favourite movie = ....")
# Out:
# Name = Lovely
# Your favourite movie = ....

# %%
fruit = ("mango")
price = ("40")
city = ("gumla")
print (fruit)
print (price)
print (city)
# Out:
# mango
# 40
# gumla

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("sum", number1+number2)
# Out:
# enter your first number10
# enter your second number25
# sum 35

# %%
print (8 > 5)
# Out:
# True

# %%
print (3 < 7)
# Out:
# True

# %%
#create age = 20 use if else to print adult if age >=18 otherwise minor
age = 20
if age >= 18:
    print ("adult")
else:
    print ("minor")
# Out:
# adult

# %%
#create temp = 35 print hot if temp >30 otherwise pleasant
temp = 35
if temp >30:
    print ("hot")
else:
    print ("pleasant")
# Out:
# hot

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (5):
    print ("😚🧿😍")
# Out:
# 😚🧿😍
# 😚🧿😍
# 😚🧿😍
# 😚🧿😍
# 😚🧿😍

# %%
print ("see you tomorrow for day 8!❤️")
# Out:
# see you tomorrow for day 8!❤️
