# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely32_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "python" .find("t")
print("python".find("t"))
# Out:
# 2

# %%
#find "o" in lovely
print("lovely".find("o"))
# Out:
# 1

# %%
#ask user for text and find "e"
text = input("Enter a text: ")

if "e" in text:
    print("'e' is found in the text.")
else:
    print("'e' is not found in the text.")
# Out:
# enter a text:Apple
# 4

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "mango"
print(fruit)
# Out:
# mango

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision" len("cat")
print(len("cat"))
# Out:
# 3

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Black
# Black

# %%
#Revision: "a" in apple
print("apple".count("a"))
# Out:
# 1

# %%
#print "day 32 complete!"
print("Day 32 complete!")
# Out:
# Day 32 complete!
