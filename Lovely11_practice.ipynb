# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely11_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print your favourite movie
print ("horror")
# Out:
# horror

# %%
pet = "Dog"
age = "2"
place = "gumla"
print (pet)
print (age)
print (place)
# Out:
# Dog
# 2
# gumla

# %%
colour = input("enter your favourite colour")
print (colour)
# Out:
# enter your favourite colourBlack
# Black

# %%
print (10>=10)
# Out:
# True

# %%
print (7>=9)
# Out:
# False

# %%
#create marks = 40 use if else to print pass if marks>=35 otherwise fail
marks = 40
if marks >=35:
    print ("pass")
else:
    print ("fail")
# Out:
# pass

# %%
#create score = 90 print excellent if score >=90 otherwise keep practicing
score = 90
if score >=90:
    print ("excellent")
else:
    print ("keep practicing")
# Out:
# excellent

# %%
for i in range (2,7):
    print (i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
for i in range (2):
    print ("i love python!")
# Out:
# i love python!
# i love python!

# %%
print ("see you tomorrow for day 11!❤️
