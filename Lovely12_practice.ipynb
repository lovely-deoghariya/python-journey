# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely12_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (5!= 3)
# Out:
# True

# %%
print (8!=8)
# Out:
# False

# %%
#create a variable and print it
name = "Lovely"
print (name)
# Out:
# Lovely

# %%
#check password using if else
password= "1111"
if password!= "1234":
    print ("wrong password")
else:
    print ("access granted")
# Out:
# wrong password

# %%
for i in range (1,6) :
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask age and print it
age = 21
print (age)
# Out:
# 21

# %%
#Create a colour variable and print it
colour = "black"
print (colour)
# Out:
# black

# %%
print (9!=2)
# Out:
# True

# %%
print ("keep learning")
# Out:
# keep learning

# %%
print ("Day 12 complete❤️")
# Out:
# Day 12 complete❤️
