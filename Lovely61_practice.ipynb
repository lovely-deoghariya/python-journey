# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely61_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: list insert()

# %%
#create fruits = ["Apple","Banana"]
fruits = ["Apple", "Banana"]

# %%
#Insert "Mango" at index 1
fruits = ["Apple", "Banana"]
fruits.insert(1, "Mango")

# %%
#print the list
fruits = ["Apple", "Banana"]
fruits.insert(1, "Mango")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#print first item
fruits = ["Apple", "Banana"]
print(fruits[0])
# Out:
# Apple

# %%
#print last item
fruits = ["Apple", "Banana"]
print(fruits[-1])
# Out:
# Banana

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Watermelon 🍉
# Watermelon 🍉

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: append ()
fruits = ["Apple", "Banana"]
fruits.append("Mango")
print(fruits)
# Out:
# ['Apple', 'Banana', 'Mango']

# %%
#Revision: remove()
fruits = ["Apple", "Mango", "Banana"]
fruits.remove("Mango")
print(fruits)
# Out:
# ['Apple', 'Banana']

# %%
#print "Day 61 complete!"
print("Day 61 complete!")
# Out:
# Day 61 complete!
