# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely53_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create fruit = ["Apple","Mango"]
fruits = ["Apple", "Mango"]
print(fruits)
# Out:
# ['Apple', 'Mango']

# %%
#print the list
fruits = ["Apple", "Mango"]
print(fruits)
# Out:
# ['Apple', 'Mango']

# %%
#print first list
fruits = ["Apple", "Mango"]
print(fruits[0])
# Out:
# Apple

# %%
#print 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a colour list
colors = ["Red", "Blue", "Green"]
print(colors)
# Out:
# ['Red', 'Blue', 'Green']

# %%
#Ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Lichi
# Lichi

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: input()
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Vishal
# Hello Vishal

# %%
#Revision: f-string
name = input("Enter your name: ")
print(f"Hello {name}")
# Out:
# Enter your name: Vishal
# Hello Vishal

# %%
#print "Day 53 complete!"
print("Day 53 complete!")
# Out:
# Day 53 complete!
