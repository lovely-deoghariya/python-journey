# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely27_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print "Hi" *3
print("Hi "*3)
# Out:
# Hi Hi Hi

# %%
#print "⭐" *5
print("⭐"*5)
# Out:
# ⭐⭐⭐⭐⭐

# %%
#create smile = "😊" and print smile*4
smile = "😊"
print(smile*5)
# Out:
# 😊😊😊😊😊

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "Apple"
print(fruit)
# Out:
# Apple

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:White
# White

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 27 complete!"
print("Day 27 complete!"
