# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/lovely50_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask user for name
name = input("Enter your name:")
print(name)
# Out:
# Enter your name:Lovely
# Lovely

# %%
#use strip()
name = input("Enter your name: ")
print(name.strip())
# Out:
# Enter your name: Vishal
# Vishal

# %%
#use title()
name = input("Enter your name: ")
print(name.title())
# Out:
# Enter your name: Lovely
# Lovely

# %%
#print greeting with f-string
name = input("Enter your name: ")
print(f"Hello, {name}!")
# Out:
# Enter your name: Vishal
# Hello, Vishal!

# %%
#print len(name)
name = "lovely"
print(len(name))
# Out:
# 6

# %%
#check isalpha()
name = input("Enter your name: ")
print(name.isalpha())
# Out:
# Enter your name: Lovely
# True

# %%
#print first letter
name = input("Enter your name: ")
print(name[0])
# Out:
# Enter your name: Vishal
# V

# %%
#print last letter
name = input("Enter your name: ")
print(name[-1])
# Out:
# Enter your name: Vishal
# l

# %%
#Revision: upper()
name = "lovely"
print(name.upper())
# Out:
# LOVELY

# %%
#print "Day 50 complete!"
print("Day 50 complete!")
# Out:
# Day 50 complete!
