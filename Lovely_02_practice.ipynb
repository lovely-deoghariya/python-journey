# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely_02_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("python is fun")
# Out:
# python is fun

# %%
your_name = "vishal"
my_name = "lovely"
print (your_name)
print (my_name)
# Out:
# vishal
# lovely

# %%
a=15
b=5
print (a+b) #addition
print (a-b) #subtraction
print (a*b) #multiplication
print (a/b) #division
# Out:
# 20
# 10
# 75
# 3.0

# %%
city = input ("enter your city:")
print ("You live in",city)
# Out:
# enter your city:Gumla
# You live in Gumla

# %%
food = input("what is your favourite food ?")
print("I hope we eat together someday!❤️")
# Out:
# what is your favourite food ?Biryani
# I hope we eat together someday!❤️

# %%
number = int(input("enter a number:"))
print ( number*number)
# Out:
# enter a number:6
# 36

# %%
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (5):
    print ("I can do this")
# Out:
# I can do this
# I can do this
# I can do this
# I can do this
# I can do this

# %%
print(20==20)
# Out:
# True

# %%
print ("See you tomorrow for day 3 !❤️")
# Out:
# See you tomorrow for day 3 !❤️
