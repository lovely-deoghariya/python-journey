# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely34_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "python" .isalpha()
print("python".isalpha())
# Out:
# True

# %%
#print "abc123" .isalpha()
print("abc123".isalpha())
# Out:
# False

# %%
#ask user for text and check .isalpha()
text = input("enter text: ")
print(text.isalpha())
# Out:
# enter text: Python
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "grapes"
print(fruit)
# Out:
# grapes

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Orange
# Orange

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: strip()
text = input("enter text:")
print(text.strip())
# Out:
# enter text:Lovely
# Lovely

# %%
#Revision: Replace()
text = input("enter text:")
print(text.replace("a", "*"))
# Out:
# enter text:Banana
# B*n*n*

# %%
#print "day 34 complete!"
print("Day 34 complete!")
