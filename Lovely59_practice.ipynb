# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely59_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: check items using "in"

# %%
#check if "Apple" is in the list
fruits = ["Apple", "Mango", "Banana"]
print("Apple" in fruits)
# Out:
# True

# %%
#check if "Grapes" is in the list
fruits = ["Apple", "Mango", "Banana"]
print("Grapes" in fruits)
# Out:
# False

# %%
#ask user for a fruit and check if it's in the list
fruits = ["Apple", "Mango", "Banana"]
fruit = input("Enter a fruit: ")
print(fruit in fruits)
# Out:
# Enter a fruit: Lichi
# False

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a colour list
colors = ["Red", "Blue", "Green"]

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: append()
fruits = ["Apple", "Mango"]
fruits.append("Banana")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana']

# %%
#Revision: remove ()
fruits = ["Apple", "Mango", "Banana"]
fruits.remove("Mango")
print(fruits)
# Out:
# ['Apple', 'Banana']

# %%
#Revision: first item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[0])
# Out:
# Apple

# %%
#print "Day 59 complete!"
print("Day 59 complete!")
# Out:
# Day 59 complete!
