# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely58_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Today's new concept: change list items

# %%
#create a fruits list
fruits = ["Apple", "Mango", "Banana"]

# %%
#Replace "Apple" with "orange"
fruits = ["Apple", "Mango", "Banana"]
fruits[0] = "Orange"

# %%
#print the updated list
fruits = ["Apple", "Mango", "Banana"]
fruits[0] = "Orange"
print(fruits)
# Out:
# ['Orange', 'Mango', 'Banana']

# %%
#print the second item
fruits = ["Apple", "Mango", "Banana"]
print(fruits[1])
# Out:
# Mango

# %%
#print number 1 to 5
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#ask favourite fruit
fruit = input("Enter your favorite fruit: ")
print(fruit)
# Out:
# Enter your favorite fruit: Lichi
# Lichi

# %%
#print "keep learning!"
print("Keep Learning!")
# Out:
# Keep Learning!

# %%
#Revision: remove()
fruits = ["Apple", "Mango", "Banana"]
fruits.remove("Mango")
print(fruits)
# Out:
# ['Apple', 'Banana']

# %%
#Revision: len(list)
fruits = ["Apple", "Mango", "Banana"]
print(len(fruits))
# Out:
# 3

# %%
#print "Day 58 complete!"
print("Day 58 complete!")
# Out:
# Day 58 complete!
